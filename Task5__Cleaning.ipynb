# %% [markdown]
# # Task 5: Data Cleaning using Pandas
#
# This notebook demonstrates basic data cleaning steps using Pandas.

# %%
import pandas as pd

df = pd.read_csv('tested.csv')
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# ### Missing Value Handling
# - Numerical columns filled with median
# - Categorical columns filled with mode

# %%
for col in df.select_dtypes(include='number').columns:
    df[col] = df[col].fillna(df[col].median())

for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# %% [markdown]
# ### Duplicate Removal

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Saving Cleaned Dataset

# %%
df.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# ### Final Outcome
# This task shows how Python and Pandas simplify data cleaning compared to Excel.

# %% [markdown]
# ### Dataset Loading
# The dataset was loaded using `pandas.read_csv()` to bring raw data into a DataFrame for analysis and cleaning.

# %% [markdown]
# ### Initial Data Exploration
# `.head()` and `.info()` were used to understand structure, data types, and missing values.

# %% [markdown]
# ### Missing Value Detection
# `.isnull().sum()` helped identify columns that required cleaning.

# %% [markdown]
# ### Handling Numerical Missing Values
# Numerical columns were filled with the median to reduce the effect of outliers.

# %% [markdown]
# ### Handling Categorical Missing Values
# Categorical columns were filled with the mode to preserve category consistency.

# %% [markdown]
# ### Duplicate Removal
# `.drop_duplicates()` was used to remove repeated rows and ensure data accuracy.

# %% [markdown]
# ### Data Quality Improvement
# Cleaning improved consistency and reliability of the dataset.

# %% [markdown]
# ### Saving Cleaned Dataset
# The cleaned dataset was saved using `.to_csv()` for future use.
